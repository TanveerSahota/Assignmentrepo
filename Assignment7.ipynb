# %%
import numpy as np
import pandas as pd

rn=102317194
np.random.seed(rn)
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
categories = ["Electronics", "Clothing", "Home & Kitchen", "Sports"]

sales_data=np.random.randint(1000, 5001, size=(12, 4))

df = pd.DataFrame(sales_data, columns=categories, index=months)

print(df.head(5))
print(df.describe())


totals = df.sum()
print(totals)
totalm = df.sum(axis=1)
print(totalm)
growth_rates = df.pct_change().mean() * 100


df["Total Sales"] = totalm
df["Growth Rate"] = df["Total Sales"].pct_change() * 100

print(df)

discounted_df = df.copy()
if rn % 2 == 0:
    discounted_df["Electronics"] *= 0.9
else:
   discounted_df["Clothing"] *= 0.85

discounted_df
# Out:
#      Electronics  Clothing  Home & Kitchen  Sports
# Jan         3075      2205            1176    1551
# Feb         2982      4305            4200    3546
# Mar         2844      4104            1816    3005
# Apr         4905      2214            3567    3941
# May         1615      3198            4639    4039
#        Electronics    Clothing  Home & Kitchen       Sports
# count    12.000000    12.00000       12.000000    12.000000
# mean   3095.833333  2744.75000     3047.500000  3281.750000
# std    1162.817021  1184.70565     1232.890801  1172.946029
# min    1537.000000  1063.00000     1176.000000  1551.000000
# 25%    2434.000000  1752.00000     2054.500000  2191.750000
# 50%    2913.000000  2551.00000     3436.000000  3689.000000
# 75%    3713.000000  3571.50000     3885.750000  4125.500000
# max    4959.000000  4611.00000     4639.000000  4770.000000
# Electronics       37150
# Clothing          32937
# Home & Kitchen    36570
# Sports            39381
# dtype: int64
# Jan     8007
# Feb    15033
# Mar    11769
# Apr    14627
# May    13491
# Jun    12806
# Jul    10086
# Aug    10015
# Sep    14202
# Oct     9292
# Nov    15358
# Dec    11352
# dtype: int64
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan         3075      2205            1176    1551         8007          NaN
# Feb         2982      4305            4200    3546        15033    87.748220
# Mar         2844      4104            1816    3005        11769   -21.712233
# Apr         4905      2214            3567    3941        14627    24.284136
# May         1615      3198            4639    4039        13491    -7.766459
# Jun         2569      3394            2323    4520        12806    -5.077459
# Jul         2504      1063            2134    4385        10086   -21.240044
# Aug         2224      1686            3781    2324        10015    -0.703946
# Sep         3458      4611            1363    4770        14202    41.807289
# Oct         1537      1495            4587    1673         9292   -34.572595
# Nov         4959      2888            3679    3832        15358    65.281963
# Dec         4478      1774            3305    1795        11352   -26.084126
#      Electronics  Clothing  Home & Kitchen  Sports  Total Sales  Growth Rate
# Jan       2767.5      2205            1176    1551         8007          NaN
# Feb       2683.8      4305            4200    3546        15033    87.748220
# Mar       2559.6      4104            1816    3005        11769   -21.712233
# Apr       4414.5      2214            3567    3941        14627    24.284136
# May       1453.5      3198            4639    4039        13491    -7.766459
# Jun       2312.1      3394            2323    4520        12806    -5.077459
# Jul       2253.6      1063            2134    4385        10086   -21.240044
# Aug       2001.6      1686            3781    2324        10015    -0.703946
# Sep       3112.2      4611            1363    4770        14202    41.807289
# Oct       1383.3      1495            4587    1673         9292   -34.572595
# Nov       4463.1      2888            3679    3832        15358    65.281963
# Dec       4030.2      1774            3305    1795        11352   -26.084126

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
df.plot(kind='line', marker='o', title='Monthly Sales Trends')
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend(loc='upper left')
plt.show()

plt.figure(figsize=(10, 5))
sns.boxplot(data=df[categories])
plt.title("Sales Distribution by Category")
plt.show()

# %%
array = np.array([[1, -2, 3], [-4, 5, -6]])
print(np.abs(array))
print(np.percentile(array, [25, 50, 75], axis=None))
print(np.percentile(array, [25, 50, 75], axis=0))
print(np.percentile(array, [25, 50, 75], axis=1))
print(np.mean(array))
print(np.median(array))
print(np.std(array))
# Out:
# [[1 2 3]
#  [4 5 6]]
# [-3.5 -0.5  2.5]
# [[-2.75 -0.25 -3.75]
#  [-1.5   1.5  -1.5 ]
#  [-0.25  3.25  0.75]]
# [[-0.5 -5. ]
#  [ 1.  -4. ]
#  [ 2.   0.5]]
# -0.5
# -0.5
# 3.8622100754188224

# %%
a = np.array([-1.8, -1.6, -0.5, 0.5, 1.6, 1.8, 3.0])
print(np.floor(a))
print(np.ceil(a))
print(np.trunc(a))
print(np.round(a))
# Out:
# [-2. -2. -1.  0.  1.  1.  3.]
# [-1. -1. -0.  1.  2.  2.  3.]
# [-1. -1. -0.  0.  1.  1.  3.]
# [-2. -2. -0.  0.  2.  2.  3.]

# %%
lst = [1, 2, 3, 4, 5]
temp = lst[1]
lst[1] = lst[3]
lst[3] = temp
print("Swapped List:", lst)
# Out:
# Swapped List: [1, 4, 3, 2, 5]

# %%
s = {10, 20, 30, 40, 50}
sl = list(s)
sl[0], sl[4] = sl[4], sl[0]
ss = set(sl)
print("Swapped Set:", ss)
# Out:
# Swapped Set: {40, 10, 50, 20, 30}
